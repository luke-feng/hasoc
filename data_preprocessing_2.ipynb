# %%
import pandas as pd

# %%
path = 'D:/UZH/other/hasoc/new/rawdata/'

# %% [markdown]
# 2021 datasets

# %%
en_train_21 = pd.read_csv(path + 'en_Hasoc2021_train.csv', header=0)
hi_train_21 = pd.read_csv(path + 'hi_Hasoc2021_train.csv', header=0)
mr_train_21 = pd.read_excel(path + 'mr_Hasoc2021_train.xlsx', header=0)

# %%
mr_train_21
# Out:
#             text_id                                               text task_1
# 0        hasoc_mr_1  भारत 15 ऑगस्ट 1947 ला स्वतंत्र झाला आणि त्यानं...    NOT
# 1        hasoc_mr_2  स्वत ला हवा तसा बाइट किंवा प्रतिक्रिया घेण्यास...    NOT
# 2        hasoc_mr_3  5 व्या नंबरची अर्थव्यवस्था आहे भारताची जगात 20...    NOT
# 3        hasoc_mr_4      च्यायला म्हणजे दुबईचा फोन ही पुडीच निघाली की.    HOF
# 4        hasoc_mr_5  ह्याला खरंतर कधीच आत टाकला पाहिजे होता. पैसा आ...    HOF
# ...             ...                                                ...    ...
# 1869  hasoc_mr_1870  आठवीत शिकत असलेल्या शिरीषकुमारने   हिंमत असेल ...    NOT
# 1870  hasoc_mr_1871  तुझा पक्ष पण हिंदुत्ववादीच आहे ना? मग आणा की ब...    NOT
# 1871  hasoc_mr_1872  च्यायला...२ महिने आधी हेच भिकारचोट केंद्राकडे ...    NOT
# 1872  hasoc_mr_1873  १ मे १९६० ला स्थापन झाल्यावर राज्याचे सुसंघटित...    NOT
# 1873  hasoc_mr_1874                             गीत भिमा तुझ्यासाठी ❣️    NOT
#
# [1874 rows x 3 columns]

# %% [markdown]
# 2020 datasets

# %%
en_train_20 = pd.read_excel(path + 'hasoc_2020_en_train_new.xlsx', header=0)
hi_train_20 = pd.read_excel(path + 'hasoc_2020_hi_train.xlsx', header=0)
de_train_20 = pd.read_excel(path + 'hasoc_2020_de_train_new.xlsx', header=0)
en_test_20 = pd.read_excel(path + 'hasoc_2020_en_test_new.xlsx', header=0)
hi_test_20 = pd.read_excel(path + 'hasoc_2020_hi_test.xlsx', header=0)
de_test_20 = pd.read_excel(path + 'hasoc_2020_de_test_new.xlsx', header=0)

# %%
en_train_20
# Out:
#           tweet_id                                               text task1  \
# 0     1.123757e+18  hate wen females hit ah nigga with tht bro 😂😂,...   HOF
# 1     1.123733e+18  RT @airjunebug: When you're from the Bay but y...   HOF
# 2     1.123734e+18  RT @DonaldJTrumpJr: Dear Democrats: The Americ...   NOT
# 3     1.126951e+18  RT @SheLoveTimothy: He ain’t on drugs he just ...   HOF
# 4     1.126864e+18  RT @TavianJordan: Summer ‘19 I’m coming for yo...   NOT
# ...            ...                                                ...   ...
# 3703  1.126887e+18  RT @FilthyArt_: TONIGHT TONIGHT TONIGHT \n\nCa...   NOT
# 3704  1.126826e+18                         RT @abbn0rmal_: Eat my ass   HOF
# 3705  1.126880e+18  RT @FlyTPA: BREAKING NEWS: TPA is about to get...   NOT
# 3706  1.130291e+18  RT @StarrThaRapper: It’s been a hr FUCK THAT G...   HOF
# 3707  1.126980e+18             You don't know who iam but i know you😄   NOT
#
#      task2                  ID
# ...

# %% [markdown]
# 2019 datasets

# %%
en_train_19 = pd.read_csv(path + 'english_dataset.tsv', header=0, delimiter='\t')
hi_train_19 = pd.read_csv(path + 'german_dataset.tsv', header=0, delimiter='\t')
de_train_19 = pd.read_csv(path + 'hindi_dataset.tsv', header=0, delimiter='\t')
en_test_19 = pd.read_csv(path + 'hasoc2019_en_test_2919.tsv', header=0, delimiter='\t')
hi_test_19 = pd.read_csv(path + 'hasoc2019_hi_test_gold_2919.tsv', header=0, delimiter='\t')
de_test_19 = pd.read_csv(path + 'hasoc_de_test_gold.tsv', header=0, delimiter='\t')

# %%
en_train_19
# Out:
#             text_id                                               text task_1  \
# 0        hasoc_en_1  #DhoniKeepsTheGlove | WATCH: Sports Minister K...    NOT
# 1        hasoc_en_2  @politico No. We should remember very clearly ...    HOF
# 2        hasoc_en_3  @cricketworldcup Guess who would be the winner...    NOT
# 3        hasoc_en_4  Corbyn is too politically intellectual for #Bo...    NOT
# 4        hasoc_en_5  All the best to #TeamIndia for another swimmin...    NOT
# ...             ...                                                ...    ...
# 5847  hasoc_en_5848  @davidfrum @trueblueusa1 That's cute and all, ...    HOF
# 5848  hasoc_en_5849  a recession issa comin' #maga #magamyass #fuck...    NOT
# 5849  hasoc_en_5850  #DoctorsFightBack  Will 'The Mad n Irrational ...    HOF
# 5850  hasoc_en_5851  #ShiningIndia #educatedindia or more like RUND...    HOF
# 5851  hasoc_en_5852  Could this be our new Prime Minister?     #Ric...    HOF
#
#      task_2 task_3
# ...

# %%
en_train_21_t2 = pd.DataFrame(en_train_21, columns=['_id', 'text', 'task_2'])
en_train_21_t2.columns = ['id', 'text', 'task_2']
hi_train_21_t2 = pd.DataFrame(hi_train_21, columns=['tweet_id', 'text', 'task_2'])
hi_train_21_t2.columns = ['id', 'text', 'task_2']

# %%
en_train_20_t2 = pd.DataFrame(en_train_20, columns=['tweet_id', 'text', 'task2'])
en_train_20_t2.columns = ['id', 'text', 'task_2']
hi_train_20_t2 = pd.DataFrame(hi_train_20, columns=['tweet_id', 'text', 'task2'])
hi_train_20_t2.columns = ['id', 'text', 'task_2']
de_train_20_t2 = pd.DataFrame(de_train_20, columns=['tweet_id', 'text', 'task2'])
de_train_20_t2.columns = ['id', 'text', 'task_2']

en_test_20_t2 = pd.DataFrame(en_test_20, columns=['tweet_id', 'text', 'task2'])
en_test_20_t2.columns = ['id', 'text', 'task_2']
hi_test_20_t2 = pd.DataFrame(hi_test_20, columns=['tweet_id', 'text', 'task2'])
hi_test_20_t2.columns = ['id', 'text', 'task_2']
de_test_20_t2 = pd.DataFrame(de_test_20, columns=['tweet_id', 'text', 'task2'])
de_test_20_t2.columns = ['id', 'text', 'task_2']

# %%
en_train_19_t2 = pd.DataFrame(en_train_19, columns=['text_id', 'text', 'task_2'])
en_train_19_t2.columns = ['id', 'text', 'task_2']
hi_train_19_t2 = pd.DataFrame(hi_train_19, columns=['text_id', 'text', 'task_2'])
hi_train_19_t2.columns = ['id', 'text', 'task_2']
de_train_19_t2 = pd.DataFrame(de_train_19, columns=['text_id', 'text', 'task_2'])
de_train_19_t2.columns = ['id', 'text', 'task_2']

en_test_19_t2 = pd.DataFrame(en_test_19, columns=['text_id', 'text', 'task_2'])
en_test_19_t2.columns = ['id', 'text', 'task_2']
hi_test_19_t2 = pd.DataFrame(hi_test_19, columns=['text_id', 'text', 'task_2'])
hi_test_19_t2.columns = ['id', 'text', 'task_2']
de_test_19_t2 = pd.DataFrame(de_test_19, columns=['text_id', 'text', 'task_2'])
de_test_19_t2.columns = ['id', 'text', 'task_2']

# %%
t1_with_ge = [en_train_21_t2, hi_train_21_t2, 
en_train_20_t2, hi_train_20_t2, de_train_20_t2,
en_test_20_t2, hi_test_20_t2, de_test_20_t2,
en_train_19_t2, hi_train_19_t2, de_train_19_t2,
en_test_19_t2, hi_test_19_t2, de_test_19_t2]

# %%
t2_with_ge = pd.concat(t1_with_ge)

# %%
t2_with_ge.to_csv('t2_with_ge.tsv', sep='\t')

# %%
t2_without_ge = [en_train_21_t2, hi_train_21_t2, 
en_train_20_t2, hi_train_20_t2, 
en_test_20_t2, hi_test_20_t2, 
en_train_19_t2, hi_train_19_t2, 
en_test_19_t2, hi_test_19_t2]
t2_without_ge = pd.concat(t2_without_ge)

# %%
t2_without_ge.to_csv('t2_without_ge.tsv', sep='\t')

# %%
t2_only21 = [en_train_21_t2, hi_train_21_t2]
t2_only21 = pd.concat(t2_only21)

# %%
t2_only21.to_csv('t2_only21.tsv', sep='\t')

# %%
import pandas as pd

# %%
raw_data = pd.read_csv('t2_without_ge.tsv',sep='\t')

# %%
non = raw_data.loc[raw_data['task_2'] == 'NONE']
hate = raw_data.loc[raw_data['task_2'] == 'HATE']
offn = raw_data.loc[raw_data['task_2'] == 'OFFN']
prfn = raw_data.loc[raw_data['task_2'] == 'PRFN']

# %%
balanced_dataset=[non.sample(3351), hate.sample(3351), offn.sample(3351), prfn.sample(3351)]
balanced_dataset = pd.concat(balanced_dataset)
balanced_dataset.to_csv('balanced_dataset.tsv',sep='\t')

# %%
balanced_dataset.sample(10)
# Out:
#        Unnamed: 0                        id  \
# 11099        2662    1.1301713944599512e+18
# 7074         3231        hi_hasoc_2021_1981
# 25381        1560             hasoc_de_1561
# 6712         2869        hi_hasoc_2021_5311
# 15961         853      1.13006697306334e+18
# 11333        2896    1.1269222852255212e+18
# 15416         308    1.1237655346198404e+18
# 189           189  60c5d6bf5659ea5e55df038d
# 20876        2907             hasoc_en_2908
# 1878         1878  60c5d6bf5659ea5e55df0054
#
#                                                     text task_2
# 11099  RT @tressabeu: people will apologize and go ba...   PRFN
# 7074   @BiharTakChannel @khesariLY और हाँ तुमने बोला ...   NONE
# 25381  Find ich irgendwie witzig, wenn ein schwuler G...   NONE
# 6712   60 का दशक, फ़िल्म ‘मेहरबान‘ का गाना था, “मेरा ...   OFFN
# 15961  RT @NiteLoops: Kim Kardashian and Kanye West n...   OFFN
# 11333                    Can’t let you fuck up the vibes   PRFN
# ...
